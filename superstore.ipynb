# %%
import pandas as pd
df=pd.read_excel("https://github.com/singhrau0/Big-Data-Preprocessing/raw/refs/heads/main/Sample%20-%20Superstore.xls",sheet_name="Orders")

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
pd.set_option("display.max_columns",None)

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df[['Category','Sales']].groupby('Category').sum()
# Out:
#                        Sales
# Category
# Furniture        741999.7953
# Office Supplies  719047.0320
# Technology       836154.0330

# %%
#FINDOUT the average profit made by each region in each category
#group by region, category
#profit-average
df[['Category','Region','Profit']].groupby(['Category','Region']).mean()
# Out:
#                             Profit
# Category        Region
# Furniture       Central  -5.968918
#                 East      5.068496
#                 South    20.395199
#                 West     16.272914
# Office Supplies Central   6.244712
#                 East     23.957114
#                 South    20.086827
#                 West     27.733183
# Technology      Central  80.231981
#                 East     88.714084
#                 South    68.231506
#                 West     73.962687

# %%
#find out average,minimum,max sales in each region
gt=df[['Region','Sales']].groupby('Region')
gt.mean()
gt.max()
gt.min()
# Out:
#          Sales
# Region
# Central  0.444
# East     0.852
# South    1.167
# West     0.990

# %%
gt.aggregate({'Sales':['min','max','mean']})
# Out:
#          Sales
#            min        max        mean
# Region
# Central  0.444  17499.950  215.772661
# East     0.852  11199.968  238.336110
# South    1.167  22638.480  241.803645
# West     0.990  13999.960  226.493233

# %%
#find out average and total sales and avg and max proft for each category in each region
gr=df[['Region','Category','Sales','Profit']].groupby(['Region','Category'])

# %%
gr.aggregate({'Sales':['mean','sum'],'Profit':['mean','max']})
# Out:
#                               Sales                  Profit
#                                mean          sum       mean        max
# Region  Category
# Central Furniture        340.534644  163797.1638  -5.968918   770.3520
#         Office Supplies  117.458801  167026.4150   6.244712  4946.3700
#         Technology       405.753124  170416.3120  80.231981  8399.9760
# East    Furniture        346.574383  208291.2040   5.068496  1013.1270
#         Office Supplies  120.044425  205516.0550  23.957114  1453.1238
#         Technology       495.278469  264973.9810  88.714084  5039.9856
# South   Furniture        353.309289  117298.6840  20.395199   746.4078
#         Office Supplies  126.282727  125651.3130  20.086827  3177.4750
#         Technology       507.753952  148771.9080  68.231506  2799.9840
# West    Furniture        357.302325  252612.7435  16.272914   629.0100
#         Office Supplies  116.422377  220853.2490  27.733183  1906.4850
# ...

# %%
#find out top2 subcategory based on total profit made in each region
gr=df[['Region','Sub-Category','Profit']].groupby(['Region','Sub-Category'])

# %%
gr.sum()
# Out:
#                           Profit
# Region  Sub-Category
# Central Accessories    7251.6306
#         Appliances    -2638.6175
#         Art            1195.1591
#         Binders       -1043.6369
#         Bookcases     -1997.9043
# ...                          ...
# West    Paper         12119.2364
#         Phones         9110.7426
#         Storage        8645.3222
#         Supplies        626.0465
#         Tables         1482.6073
#
# [68 rows x 1 columns]

# %%
grnew=gr.sum().sort_values(by=['Region','Profit'],ascending=False)

# %%
grnew
# Out:
#                           Profit
# Region  Sub-Category
# West    Copiers       19327.2351
#         Accessories   16484.5983
#         Binders       16096.8016
#         Paper         12119.2364
#         Phones         9110.7426
# ...                          ...
# Central Machines      -1486.0666
#         Bookcases     -1997.9043
#         Appliances    -2638.6175
#         Tables        -3559.6504
#         Furnishings   -3906.2168
#
# [68 rows x 1 columns]

# %%
grnew.groupby('Region').head(2)
# Out:
#                           Profit
# Region  Sub-Category
# West    Copiers       19327.2351
#         Accessories   16484.5983
# South   Phones        10767.2753
#         Accessories    7004.5424
# East    Copiers       17022.8418
#         Phones        12314.6860
# Central Copiers       15608.8413
#         Phones        12323.0267

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
import datetime as dt

# %%
df['Year']=df['Order Date'].dt.year

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
#find out least profitable Sub-category in each year
gr=df[['Year','Sub-Category','Profit']].groupby(['Year','Sub-Category'])

# %%
gr_new=gr.sum().sort_values(by=['Year','Profit'],ascending=True)

# %%
gr_new.groupby('Year').head(2)
# Out:
#                       Profit
# Year Sub-Category
# 2014 Tables       -3124.0427
#      Bookcases     -346.1707
# 2015 Tables       -3509.8019
#      Bookcases    -2755.2302
# 2016 Tables       -2950.9418
#      Supplies      -698.9639
# 2017 Tables       -8140.6947
#      Machines     -2869.2156

# %%
# pivot_table
# find out of total sales and minimum sale,total profit and average discount for each category in each year
df.pivot_table(index=['Year','Category'],values=['Sales','Profit','Discount'],aggfunc={'Sales':['sum','min'],'Profit':['sum'],'Discount':['mean']})
# Out:
#                       Discount      Profit  Sales
#                           mean         sum    min          sum
# Year Category
# 2014 Furniture        0.182090   5457.7255  3.480  157192.8531
#      Office Supplies  0.156368  22593.4161  0.852  151776.4120
#      Technology       0.136620  21492.8325  1.980  175278.2330
# 2015 Furniture        0.168783   3015.2029  2.960  170518.2370
#      Office Supplies  0.160274  25099.5338  0.984  137233.4630
#      Technology       0.126895  33503.8670  2.376  162780.8090
# 2016 Furniture        0.176904   6959.9531  2.328  198901.4360
#      Office Supplies  0.152107  35061.2292  0.836  183939.9820
#      Technology       0.136601  39773.9920  1.980  226364.1800
# 2017 Furniture        0.169854   3018.3913  1.892  215387.2692
#      Office Supplies  0.160040  39736.6217  0.444  246097.1750
#      Technology       0.130288  50684.2566  0.990  271730.8110

# %%
#find out avg and minimun discount,total profit and total sales made in each month for each category

# %%
df['Month']=df['Order Date'].dt.month

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
#find out avg and minimun discount,total profit and total sales made in each month for each category
df.pivot_table(index=['Month','Category'],values=['Profit','Discount','Sales'],aggfunc={'Profit':['sum'],'Discount':['mean','min'],'Sales':['sum']})
# Out:
#                        Discount           Profit        Sales
#                            mean  min         sum          sum
# Month Category
# 1     Furniture        0.157037  0.0  -1944.2130   31569.2416
#       Office Supplies  0.144493  0.0   6243.7654   33233.8310
#       Technology       0.158904  0.0   4834.8937   30121.7630
# 2     Furniture        0.178889  0.0    693.5796   15765.9204
#       Office Supplies  0.148023  0.0   4274.0190   20641.9130
#       Technology       0.106667  0.0   5327.0121   23343.4180
# 3     Furniture        0.182143  0.0    771.9875   50768.2758
#       Office Supplies  0.149034  0.0  10455.6295   56385.6430
#       Technology       0.145775  0.0  17367.0702   97851.5700
# 4     Furniture        0.163551  0.0   1460.3261   40698.5836
#       Office Supplies  0.171599  0.0   4747.6876   49433.2700
#       Technology       0.130631  0.0   5379.4226   47630.2750
# 5     Furniture        0.187267  0.0   2302.2981   48365.1307
# ...

# %%
#what are the highest revenue generating Subcategory in year 2015

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 for label in df:
# ----> 2     plt.hist(df[df["outcome"]==1])
#
# NameError: name 'plt' is not defined
