# %%
import pandas as pd

# %%
df=pd.read_csv("https://github.com/singhrau0/Big-Data-Preprocessing/raw/refs/heads/main/Leads.csv")
df
# Out:
#                                Prospect ID  Lead Number  \
# 0     7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737
# 1     2a272436-5132-4136-86fa-dcc88c88f482       660728
# 2     8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727
# 3     0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719
# 4     3256f628-e534-4826-9d63-4a8b88782852       660681
# ...                                    ...          ...
# 9235  19d6451e-fcd6-407c-b83b-48e1af805ea9       579564
# 9236  82a7005b-7196-4d56-95ce-a79f937a158d       579546
# 9237  aac550fe-a586-452d-8d3c-f1b62c94e02c       579545
# 9238  5330a7d1-2f2b-4df4-85d6-64ca2f6b95b9       579538
# 9239  571b5c8e-a5b2-4d57-8574-f2ffb06fdeff       579533
#
#                   Lead Origin     Lead Source Do Not Email Do Not Call  \
# 0                         API      Olark Chat           No          No
# 1                         API  Organic Search           No          No
# 2     Landing Page Submission  Direct Traffic           No          No
# ...

# %%
pd.set_option("display.max_columns",None)
df
# Out:
#                                Prospect ID  Lead Number  \
# 0     7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737
# 1     2a272436-5132-4136-86fa-dcc88c88f482       660728
# 2     8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727
# 3     0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719
# 4     3256f628-e534-4826-9d63-4a8b88782852       660681
# ...                                    ...          ...
# 9235  19d6451e-fcd6-407c-b83b-48e1af805ea9       579564
# 9236  82a7005b-7196-4d56-95ce-a79f937a158d       579546
# 9237  aac550fe-a586-452d-8d3c-f1b62c94e02c       579545
# 9238  5330a7d1-2f2b-4df4-85d6-64ca2f6b95b9       579538
# 9239  571b5c8e-a5b2-4d57-8574-f2ffb06fdeff       579533
#
#                   Lead Origin     Lead Source Do Not Email Do Not Call  \
# 0                         API      Olark Chat           No          No
# 1                         API  Organic Search           No          No
# 2     Landing Page Submission  Direct Traffic           No          No
# ...

# %%
df.isnull().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %%
df['Lead Source'].unique()
# Out:
# <StringArray>
# [       'Olark Chat',    'Organic Search',    'Direct Traffic',
#             'Google',    'Referral Sites',  'Welingak Website',
#          'Reference',            'google',          'Facebook',
#                  nan,              'blog', 'Pay per Click Ads',
#               'bing',      'Social Media',           'WeLearn',
#         'Click2call',         'Live Chat',  'welearnblog_Home',
#     'youtubechannel',           'testone',     'Press_Release',
#             'NC_EDM']
# Length: 22, dtype: str

# %%
df['Lead Source']=df['Lead Source'].replace({'google':'Google'},inplace=True)
# Out:
# C:\Users\asifs\AppData\Local\Temp\ipykernel_25576\2509940126.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Lead Source']=df['Lead Source'].replace({'google':'Google'},inplace=True)

# %%
df['Lead Source'].fillna('Google',inplace=True)
# Out:
# C:\Users\asifs\AppData\Local\Temp\ipykernel_25576\2868277656.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Lead Source'].fillna('Google',inplace=True)
# 0           Olark Chat
# 1       Organic Search
# 2       Direct Traffic
# 3       Direct Traffic
# 4               Google
#              ...
# ...

# %%
df.isnull().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %%
df.loc[df['Lead Source'].isnull(),'Lead Source']='Google'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9235    False
# 9236    False
# 9237    False
# 9238    False
# 9239    False
# Name: Lead Source, Length: 9240, dtype: bool

# %%
df.isnull().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                         0
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %%
df.isnull().sum()
df['TotalVisits'].mode()
# Out:
# 0    0.0
# Name: TotalVisits, dtype: float64

# %%
df['TotalVisits'].unique()
# Out:
# array([  0.,   5.,   2.,   1.,   4.,   8.,  11.,   6.,   3.,   7.,  13.,
#         17.,  nan,   9.,  12.,  10.,  16.,  14.,  21.,  15.,  22.,  19.,
#         18.,  20.,  43.,  30.,  23.,  55., 141.,  25.,  27.,  29.,  24.,
#         28.,  26.,  74.,  41.,  54., 115., 251.,  32.,  42.])

# %%
df.loc[df['TotalVisits'].isnull(),'TotalVisits']=0.0

# %%
df.isnull().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                         0
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                         0
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %%
df[df['Page Views Per Visit'].isnull()]
df["Page Views Per Visit"].unique()
df["Page Views Per Visit"].mean()
# Out:
# np.float64(2.361888528138528)

# %%
df.loc[df["Page Views Per Visit"].isnull(),'Page Views Per Visit']=2.3

# %%
df.isnull().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                         0
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                         0
# Total Time Spent on Website                         0
# Page Views Per Visit                                0
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %%
df['Last Activity'].unique()
df[df['Last Activity'].isnull()]
df['Last Activity'].mode()
# Out:
# 0    Email Opened
# Name: Last Activity, dtype: str

# %%
df.loc[df["Last Activity"].isnull(),'Last Activity']="Email Opened"

# %%
df.isnull().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                         0
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                         0
# Total Time Spent on Website                         0
# Page Views Per Visit                                0
# Last Activity                                       0
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %%
df['Country'].unique()
# Out:
# <StringArray>
# [                   nan,                'India',               'Russia',
#                'Kuwait',                 'Oman', 'United Arab Emirates',
#         'United States',            'Australia',       'United Kingdom',
#               'Bahrain',                'Ghana',            'Singapore',
#                 'Qatar',         'Saudi Arabia',              'Belgium',
#                'France',            'Sri Lanka',                'China',
#                'Canada',          'Netherlands',               'Sweden',
#               'Nigeria',            'Hong Kong',              'Germany',
#   'Asia/Pacific Region',               'Uganda',                'Kenya',
#                 'Italy',         'South Africa',             'Tanzania',
#               'unknown',             'Malaysia',              'Liberia',
#           'Switzerland',              'Denmark',          'Philippines',
#            'Bangladesh',              'Vietnam',            'Indonesia']
# ...

# %%
df['Country'].describe()
# Out:
# count      6779
# unique       38
# top       India
# freq       6492
# Name: Country, dtype: object

# %%
df['Country']=df['Country'].replace({"Unknown":'NaN'},inplace=True)
# Out:
# C:\Users\asifs\AppData\Local\Temp\ipykernel_25576\846363130.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Country']=df['Country'].replace({"Unknown":'NaN'},inplace=True)

# %%
df['Country'].unique()
# Out:
# <StringArray>
# [                   nan,                'India',               'Russia',
#                'Kuwait',                 'Oman', 'United Arab Emirates',
#         'United States',            'Australia',       'United Kingdom',
#               'Bahrain',                'Ghana',            'Singapore',
#                 'Qatar',         'Saudi Arabia',              'Belgium',
#                'France',            'Sri Lanka',                'China',
#                'Canada',          'Netherlands',               'Sweden',
#               'Nigeria',            'Hong Kong',              'Germany',
#   'Asia/Pacific Region',               'Uganda',                'Kenya',
#                 'Italy',         'South Africa',             'Tanzania',
#               'unknown',             'Malaysia',              'Liberia',
#           'Switzerland',              'Denmark',          'Philippines',
#            'Bangladesh',              'Vietnam',            'Indonesia']
# ...

# %%
df['Country']=df['Country'].replace({'Country':'NaN'},inplace=True)
df['Country'].mode()
# Out:
# C:\Users\asifs\AppData\Local\Temp\ipykernel_25576\1842308055.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Country']=df['Country'].replace({'Country':'NaN'},inplace=True)
# 0    India
# Name: Country, dtype: str

# %%
df.loc[df['Country'].isnull(),'Country']='India'
df.isnull().sum()
df['Specialization'].unique()
df[df['Specialization'].isnull()]
df['Specialization'].mode()
df.loc[df['Specialization'].isnull(),'Specialization']='Select'
df.isnull().sum()
df[df['How did you hear about X Education'].isnull()]
df['How did you hear about X Education'].unique()
# Out:
# <StringArray>
# [               'Select',         'Word Of Mouth',                 'Other',
#                      nan,         'Online Search',      'Multiple Sources',
#         'Advertisements', 'Student of SomeSchool',                 'Email',
#           'Social Media',                   'SMS']
# Length: 11, dtype: str

# %%
df['How did you hear about X Education'].mode()
# Out:
# 0    Select
# Name: How did you hear about X Education, dtype: str

# %%
df['Country'].unique()
# Out:
# <StringArray>
# [               'India',               'Russia',               'Kuwait',
#                  'Oman', 'United Arab Emirates',        'United States',
#             'Australia',       'United Kingdom',              'Bahrain',
#                 'Ghana',            'Singapore',                'Qatar',
#          'Saudi Arabia',              'Belgium',               'France',
#             'Sri Lanka',                'China',               'Canada',
#           'Netherlands',               'Sweden',              'Nigeria',
#             'Hong Kong',              'Germany',  'Asia/Pacific Region',
#                'Uganda',                'Kenya',                'Italy',
#          'South Africa',             'Tanzania',              'unknown',
#              'Malaysia',              'Liberia',          'Switzerland',
#               'Denmark',          'Philippines',           'Bangladesh',
#               'Vietnam',            'Indonesia']
# Length: 38, dtype: str
