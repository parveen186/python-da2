# %%
dataframe=read("sales.csv"")
# Out:
#   Cell In[21], line 1
#     dataframe=read("sales.csv"")
#                               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
dataframe=pd_read("sales.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dataframe=pd_read("sales.csv")
#
# NameError: name 'pd_read' is not defined

# %%
import pandas as pd

# %%
df=pd.read_csv("sales.csv")

# %%
numbers=[1,2,3,4,5]
for n in numbers :
    print(n=n*2)

# %%
age=25
name="john"
height=5.8
print(age)
print(name)
print(height)
# Out:
# 25
# john
# 5.8

# %%
print("hello")
# Out:
# hello

# %%
type(name)

type(age)
# Out:
# int

# %%
100
type(100)
# Out:
# int

# %%
a=10
b=20
if b>a+10:
    print(a)
    
print(a)
# Out:
# 10

# %%
x=[2,3,1]
if x[0]+x[1]>x[2] and x[1]+x[2]>x[0] and x[0]+x[2]>x[1]:
            print("it is a triangle")
else:
    print("it is not a traing")
# Out:
# it is not a traing

# %%
nums=[10,20,30,40,50,60,70]
# Out:
# [20, 10]

# %%
x="i love parveen"
x=x[::]
print(x)
# Out:
# i love parveen

# %%
# dictionary
# take a list of data from 1 to 10 reverse the list  convert into tuple 
# then try to remove last 3 elements if not possible convert back in list and then remove
# finally convert the list into sets, then find the intersection using original list
lst=[1,2,3,4,5,5,6,7,7]
reversed_lst=lst[::-1]
print(reversed_lst)
t=tuple(reversed_lst)
print(t)
# Out:
# [7, 7, 6, 5, 5, 4, 3, 2, 1]
# (7, 7, 6, 5, 5, 4, 3, 2, 1)

# %%
x=["hello",2,3,4,5,6,7,8,"parveen"]
print(x)
if type(x[0])== str and type(x[-1])==str:
     if x[0].isalpha():
          print("first data point is alphabetical")
     elif x[0].isnumeric():
           print("first data point is Numerical")
     elif x[0].isalnum():
          print("first alphabet is alphanumeric")
     
     else:
          print("it is having special character")

     if x[-1].isalpha():
          print("last data point is alphabetical")
     elif x[-1].isnumeric():
           print("last data point is Numerical")
     elif x[-1].isalnum():
          print("lastalphabet is alphanumeric")
     
     else:
          print("it is having special character")
# Out:
# ['hello', 2, 3, 4, 5, 6, 7, 8, 'parveen']
# first data point is alphabetical
# last data point is alphabetical

# %%
#looping
#while loop
#for loop
#recursion 
x=10
while x>10:
   print(x)
   x=x-1

# %%
#print all numnbers from 9 to 99 in multiple of 9
x=1
while x<99:
    print(x,end=",")
    x=x*9

# %%
#write a code to check wheather a given number is divisible by 3 and 4 both.
x=int(input("Enter a Number: "))
if x%3==0 and x%4==0 :
    print("it is divisible by 3 and 4")
else:
    print("it is not divisible by 3 and 4")

# %%
#take a input number from user and print table of that number
x=int(input("enter a number:"))
n=1
while(n<=10):
  print(x*n)
  n=n+1

# %%
#print the factors of given number in x
x=int(input())
n=1
while(n<=100):
    if(x%n==0):
        print(n)
        n=n+1

# %%
n=int(input("enter a number:"))
x=2
while x<n:
    if n%x==0:
        print("it is a not a prime")
        break
    elif x==n-1:
        print("prime")
    else:
        pass
x=x+1
